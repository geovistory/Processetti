# %%
import json
import pprint
from collections import Counter
from operator import itemgetter
import csv
from dotmap import DotMap
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# pulizzia delle stringhe

def clean_up_str(string):
    a = ''
    if string:
        a = string.replace('\xa0', '').replace('  ', ' ').strip()
    return a  



# calcolo dell'anno (medio)

def date(r_col):

    lista=[]
    for v in r_col['values']:
        if v.value.timePrimitive:
            lista.append(int(v.value.timePrimitive.label[:4]))
            
    if len(lista)>=1:
        return int(np.rint(np.mean(lista)))
    else:
        return np.nan




# sintesi time-spen (anno medio: begin, at some time, end)

def datatio(r_col_begin, r_col_someTime, r_col_end, element):

    begin, some_time, end = date(r_col_begin), date(r_col_someTime), date(r_col_end)
    element+= [begin, some_time, end]

    return(element)

# %% [markdown]
# ## Processetti overview

# %%
file = 'geovistory_query_exports/nb_overwiev_processetti_20220510.json'

with open(file, encoding='utf-8') as json_file:
    data = json.load(json_file)

dmData = DotMap(data)
dm_r = dmData.rows

# %%
### Processetti list = psl

psl=[['volume', 'section', 'number_archival_units', 'pk_processetto', 'enquiry', 'motivation_type',
 'start_date','end_date', 'anno', 'id_union', 'number_union']]


for r in dm_r:
    element = []
    # volume
    element += ['-'.join([v.entity_label for v in r.col_0.entities]) if len(r.col_0.entities)>=1 else np.nan]   

    # sezione (unità archivistica)
    element += [clean_up_str(r.col_1.entities[0].entity_label)]

    # numero di section per enquiry 
    element += [len(r.col_1.entities)]

    # enquiry 
    element += [r.col_2.entity.pk_entity, clean_up_str(r.col_2.entity.entity_label)]
   
    # motivation type
    element += [clean_up_str('; '.join([v.entity_label for v in r.col_3.entities])) if len(r.col_3.entities)>=1 else np.nan]

    # arco e anno processetto
    valor = []
    if len(r.col_4['values']) == 0:
        element += [np.nan, np.nan, np.nan]
    else:
        for v in  r.col_4['values']:
            valor.append(int(v.value.timePrimitive.label[:4]))
        element += [r.col_4['values'][0]['value'].timePrimitive.label[:10], r.col_4[
            'values'][len(r.col_4['values'])-1]['value'].timePrimitive.label[:10], round(np.mean(valor))]

    # union
    if len(r.col_5.entities)==1:
        element += [r.col_5.entities[0].pk_entity, len(r.col_5.entities)]
    elif len(r.col_5.entities)>1:
        element += ['-'.join([str(v.pk_entity) for v in r.col_5.entities]) if len(r.col_5.entities)>=1 else np.nan, len(r.col_5.entities)]  
    else:
        element += [np.nan, 0]
        
    psl.append(element)
    

df_proc = pd.DataFrame(psl[1:], columns=psl[0])  
df_proc.head()
# Out:
#   volume                                            section  \
# 0  EM 04   Processetto di Giovanni di Michele (da Cessalto)
# 1  EM 05  Processetto di Francesco di Vincenzo Moscato (...
# 2  EM 04  Processetto di Pietro di Gennaro Costinovi (da...
# 3  EM 05  Processetto di Orsola di Angelo Collotis (da V...
# 4  EM 05  Processetto di Ortensia di Leonardo Verona (da...
#
#    number_archival_units  pk_processetto  \
# 0                      1         1006519
# 1                      1         1006729
# 2                      1         1006883
# 3                      1         1007147
# 4                      1         1007355
#
#                                              enquiry  \
# 0                  Giovanni di Michele (da Cessalto)
# 1  Francesco di Vincenzo Moscato (da Fabriano, te...
# 2  Pietro di Gennaro Costinovi (da Bergamo, tesse...
# 3            Orsola di Angelo Collotis (da Visinale)
# 4           Ortensia di Leonardo Verona (da Venzone)
#
#              motivation_type  start_date    end_date    anno id_union  \
# 0  Stato libero di “foresto”  1597-05-23  1597-05-23  1597.0      NaN
# 1  Stato libero di “foresto”  1598-12-27  1598-12-27  1598.0      NaN
# 2  Stato libero di “foresto”  1597-05-26  1597-05-26  1597.0      NaN
# 3  Stato libero di “foresto”  1598-12-29  1598-12-29  1598.0      NaN
# 4  Stato libero di “foresto”  1598-12-29  1598-12-29  1598.0      NaN
#
#    number_union
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
df_proc.volume.unique()
# Out:
# array(['EM 04', 'EM 05', 'EM 25', 'EM 04-EM 06', 'EM 01', 'EM 02',
#        'EM 07', 'EM 03', 'EM 08', 'EM 06', 'EM 05-EM 06', 'FC 22',
#        'FC 20', 'FC 21', 'EM 16', 'EM 53', 'EM 40', 'EM 11', 'EM 27',
#        'EM 17', 'EM 18', 'EM 26', 'EM 04-EM 05'], dtype=object)

# %% [markdown]
# ### Errori di compilazione della _Section_

# %% [markdown]
# #### Errori tipografici nella denominazione della section

# %%
# errori tipografici nella denominazione della section

df_proc.loc[df_proc.section.str.contains('(?i)processett')==False]
# Out:
#      volume                                            section  \
# 45    EM 04        Antonio di Giovanni (da Roma, salmistrator)
# 101   EM 25  Giovanni di Valentino Nardis (da Mortegliano, ...
# 785   EM 25  Alba di Giovanni Codega (da Padova) vedova di ...
# 1382  EM 07           Bandino Guerra (dalla diocesi di Ceneda)
# 1728  EM 01  Processeto di Margherita di Matteo Paulini e d...
# 2078  EM 07  Elena (dall'Istria) vedova di Antonio (da Gori...
# 2083  EM 07  Andrea di Giacomo Schianetti (da Monfalcone, v...
# 2084  EM 07  Processeto di Alessandro di Benedetto Scalioni...
# 2218  FC 22  Mandricardo di Ascanio Rebechini (da Civitanov...
# 3102  EM 18  Antonio di Gaspare (da ZImella, tesser da pann...
# 3269  EM 04   Procesetto di Vito Sainngh (da Bamberga, sartor)
# 3326  EM 01  Processeto di Margherita di Matteo Paulini e d...
# 3327  EM 01  Processeto di Margherita di Matteo Paulini e d...
# 3389  EM 04      Veronica di Nicola Gabrialibo (da Conegliano)
#
#       number_archival_units  pk_processetto  \
# 45                        1         1036013
# 101                       1         1048915
# 785                       1         1271941
# 1382                      1         1578490
# 1728                      1         1721743
# 2078                      1         1814577
# 2083                      1         1815777
# 2084                      1         1815912
# 2218                      1         1871811
# 3102                      1         2226043
# 3269                      1          764668
# 3326                      1          776278
# 3327                      1          776302
# 3389                      1          989535
#
#                                                 enquiry  \
# 45          Antonio di Giovanni (da Roma, salmistrator)
# 101   Giovanni di Valentino Nardis (da Mortegliano, ...
# 785   Alba di Giovanni Codega (da Padova) vedova di ...
# 1382           Bandino Guerra (dalla Diocesi di Ceneda)
# 1728  Bartolomeo di Pietro Baldini (da Gargnano, murer)
# 2078  Elena (dall'Istria) vedova di Antonio (da Gori...
# 2083  Andrea di Giacomo Schianetti (da Monfalcone, v...
# 2084       Alessandro di Benedetto Scallioni (da Ghedi)
# 2218  Mandricardo di Ascanio Rebechini (da Civitanov...
# 3102  Antonio di Gaspare (da Zimella, tesser da pann...
# 3269                 Vito Sainngh (da Bamberga, sartor)
# 3326             Margherita di Matteo Paulini (massera)
# 3327    Bartolomeo Evangelista Giustinelli (da Bornato)
# 3389      Veronica di Nicola Gabrialibo (da Conegliano)
#
#                      motivation_type  start_date    end_date    anno id_union  \
# 45         Stato libero di “foresto”  1597-06-18  1597-06-19  1597.0      NaN
# 101        Stato libero di “foresto”  1627-06-11  1627-06-11  1627.0      NaN
# 785   Vedovanza; Processetto atipico  1627-07-06  1627-07-06  1627.0      NaN
# 1382                       Vedovanza  1603-01-26  1603-01-26  1603.0      NaN
# 1728       Stato libero di “foresto”  1600-07-09  1600-07-09  1600.0      NaN
# 2078                       Vedovanza  1603-12-21  1603-12-21  1603.0  1814585
# 2083       Stato libero di “foresto”  1603-12-29  1603-12-29  1603.0      NaN
# 2084       Stato libero di “foresto”  1603-12-30  1603-12-30  1603.0      NaN
# 2218       Stato libero di “foresto”  1595-04-02  1595-04-02  1595.0      NaN
# 3102       Stato libero di “foresto”  1620-06-29  1620-06-29  1620.0      NaN
# 3269       Stato libero di “foresto”  1597-01-27  1597-01-27  1597.0      NaN
# 3326       Stato libero di “foresto”  1592-09-15  1592-09-15  1592.0      NaN
# 3327       Stato libero di “foresto”  1592-09-15  1592-09-15  1592.0      NaN
# 3389       Stato libero di “foresto”  1597-05-07  1597-05-07  1597.0      NaN
#
#       number_union
# 45               0
# 101              0
# 785              0
# 1382             0
# 1728             0
# 2078             1
# 2083             0
# 2084             0
# 2218             0
# 3102             0
# 3269             0
# 3326             0
# 3327             0
# 3389             0

# %% [markdown]
# #### Associazione multiple per section e (no label)

# %%
# associazione multiple per section e (no label)

verifica = pd.DataFrame(df_proc.section.value_counts()).reset_index()

df_proc[df_proc.section.isin(verifica.loc[(verifica.section>=2) & (verifica['index'].str.contains(' e ')==False)]['index']) | (df_proc.enquiry=='(no label)')]
# Out:
#      volume                                            section  \
# 277   EM 05  Processetto di Evangelista di Pietro (da Ranza...
# 773   EM 25  Processetto di Leonardo di Matteo Gallina (da ...
# 775   EM 25  Processetto di Leonardo di Matteo Gallina (da ...
# 866   EM 05  Processetto di Evangelista di Pietro (da Ranza...
# 1332  EM 06  Processetto di Gerolama di Pietro Rubeis (da C...
# 1586  EM 06  Processetto di Vincenzo di Giovanni Nante (da ...
# 1599  EM 06  Processetto di Vincenzo di Giovanni Nante (da ...
# 1603  EM 06  Processetto di Antonio di Pietro Bellotti (ber...
# 1627  EM 03  Processetto di Marietta di Floreno Cestari (da...
# 1647  EM 06   Processetto di Faustino di Bartolomeo (da Grevo)
# 1909  EM 07  Processetto di Pietro di Antonio Meneghelli (d...
# 2041  EM 07  Processetto di Giovanni Battista di Andrea Mol...
# 2042  EM 07  Processetto di Giovanni Battista di Andrea Mol...
# 2060  EM 03  Processetto di Apollonia di Leonardo Guerra (f...
# 2162  EM 06  Processetto di Adriana (da Vito d’Asio) vedova...
# 2163  EM 06  Processetto di Adriana (da Vito d’Asio) vedova...
# 2391  EM 07  Processetto di Pietro di Antonio Meneghelli (d...
# 2398  EM 53  Processetto di Giovanni Battista di Tommaso To...
#
#       number_archival_units  pk_processetto  \
# 277                       1         1088023
# 773                       1         1270290
# 775                       1         1270445
# 866                       1         1297960
# 1332                      1         1566544
# 1586                      1         1673438
# 1599                      1         1675607
# 1603                      1         1676522
# 1627                      1         1680487
# 1647                      1         1683739
# 1909                      1         1780156
# 2041                      1         1806269
# 2042                      1         1806272
# 2060                      1         1808970
# 2162                      1         1856808
# 2163                      1         1856825
# 2391                      1         1980349
# 2398                      1         1984568
#
#                                                 enquiry  \
# 277                                          (no label)
# 773         Leonardo di Matteo Gallina (da Portogruaro)
# 775                                          (no label)
# 866   Evangelista di Pietro Crescenzi (da Ranzanico,...
# 1332                                         (no label)
# 1586  Vincenzo di Giovanni Nante (da Bologna, mercante)
# 1599                                         (no label)
# 1603                                         (no label)
# 1627                                         (no label)
# 1647                                         (no label)
# 1909  Pietro di Antonio Meneghelli (da Ampezzo, mara...
# 2041                                         (no label)
# 2042  Giovanni Battista di Andrea Molendinari (dalla...
# 2060                                         (no label)
# 2162  Adriana (da Vito d’Asio) vedova di Tommaso di ...
# 2163            Martino di Antonio Druella (dal Cadore)
# 2391                 Ambrogio Meneghelli (da Baldenich)
# 2398                                         (no label)
#
#                 motivation_type  start_date    end_date    anno id_union  \
# 277   Stato libero di “foresto”  1598-11-15  1598-11-15  1598.0      NaN
# 773   Stato libero di “foresto”  1627-07-04  1627-07-04  1627.0      NaN
# 775                         NaN         NaN         NaN     NaN      NaN
# 866   Stato libero di “foresto”  1598-11-15  1598-11-15  1598.0      NaN
# 1332  Stato libero di “foresto”  1600-02-04  1600-02-04  1600.0      NaN
# 1586  Stato libero di “foresto”  1601-04-24  1601-04-24  1601.0      NaN
# 1599                        NaN         NaN         NaN     NaN      NaN
# 1603  Stato libero di “foresto”  1601-04-26  1601-04-26  1601.0      NaN
# 1627  Stato libero di “foresto”  1596-05-08  1596-05-08  1596.0      NaN
# 1647  Stato libero di “foresto”  1601-04-28  1601-04-28  1601.0      NaN
# 1909  Stato libero di “foresto”  1603-10-07  1603-10-07  1603.0      NaN
# 2041                        NaN  1603-12-14  1603-12-14  1603.0      NaN
# 2042  Stato libero di “foresto”  1603-12-14  1603-12-14  1603.0      NaN
# 2060                  Vedovanza  1596-12-26  1596-12-26  1596.0  1808933
# 2162                  Vedovanza  1601-03-27  1601-03-27  1601.0  1856817
# 2163        Processetto atipico  1601-03-27  1601-03-27  1601.0      NaN
# 2391  Stato libero di “foresto”  1649-12-31  1650-01-17  1650.0      NaN
# 2398  Stato libero di “foresto”  1650-01-04  1650-01-04  1650.0      NaN
#
#       number_union
# 277              0
# 773              0
# 775              0
# 866              0
# 1332             0
# 1586             0
# 1599             0
# 1603             0
# 1627             0
# 1647             0
# 1909             0
# 2041             0
# 2042             0
# 2060             1
# 2162             1
# 2163             0
# 2391             0
# 2398             0

# %% [markdown]
# #### Mancata corrispondenza tra nome del richiedente e denominazione del processetto

# %%
# mancata corrispondenza tra nome del richiedente e denominazione del processetto

conteggio = 0
lista_controllo = []
for i, r in df_proc.iterrows():
    if r['enquiry'][:15] not in r['section']:
        conteggio +=1
        lista_controllo.append(r.pk_processetto)


df_proc.loc[df_proc.pk_processetto.isin(lista_controllo) & (df_proc.enquiry!='(no label)')]
# Out:
#      volume                                            section  \
# 7     EM 04          Processetto di Fillippo Amis (da Bergamo)
# 254   EM 25  Processetto di Erasmo Stairo (da Valdaora, for...
# 256   EM 01  Processetto di Giacomo Vicenti (da Vicenza, te...
# 344   EM 04  Processetto di Domenico di Vincenzo Meneghini ...
# 732   EM 02  Processetto di Giovanni di Vincenzo Mendoli (n...
# 845   EM 07         Processetto di Pietro Radonini (da Rosina)
# 959   EM 25  Processetto di Teodoro di Teofilo Polens (dall...
# 1150  EM 08  Processetto di Defendi di Angelo Pizzali (da T...
# 1625  EM 03  Processetto di Francesco di Battista Bersanino...
# 1689  EM 03  Processetto di Girolamo di Giovanni Battista S...
# 1728  EM 01  Processeto di Margherita di Matteo Paulini e d...
# 1946  EM 06  Processetto di Gasparo di Antonio Tursola (da ...
# 2003  EM 03  Processetto di Giovanni di Giorgio Tapeltroche...
# 2018  EM 03  Processetto di Battista di Girolamo Corradini ...
# 2019  EM 03  Processetto di Angelo di Girolamo Caltrani (da...
# 2051  EM 03  Processetto di Angela, vedova di: Bernardo di ...
# 2124  EM 06  Processetto di Giuseppe Locatelli (da San Dani...
# 2154  FC 22  Processetto di Giulia di Vincenzo Blanchi vedo...
# 2163  EM 06  Processetto di Adriana (da Vito d’Asio) vedova...
# 2293  FC 22    Processetto di Vespasiano Bagnoli (dall’Aquila)
# 2295  FC 22  Processetto di Giacomo di Giovanni Turriani (g...
# 2297  FC 22  Processetto di Valerio (da Selva di Cadore, fa...
# 2364  FC 22  Processetto di Giovanni di Girolamo Chiappolin...
# 2391  EM 07  Processetto di Pietro di Antonio Meneghelli (d...
# 2476  EM 53  Processetto di Marghertia di Michele Dal Bon (...
# 2483  EM 53  Processetto di Giacomo di Federico Arichi (da ...
# 2768  EM 16  Processetto di Lucia Mancini vedova di Martino...
# 2865  EM 16  Processetto di Giuseppe Battistella (da Novaledo)
# 2894  EM 11  Processetto di Antonio Maria di Girolamo Corvo...
# 3309  EM 04  Processetto di Marietta di Madgalino Gomes (da...
# 3319  EM 04  Processetto di Francesco di Delaidi Gosetti (d...
# 3339  EM 04           Processetto di Leonardo Pavini (da Lion)
# 3358  EM 04          Processetto di Olimpia di Furiano Roberti
# 3383  EM 04  Processetto di Bartolomeo di Domenico Bernacio...
# 3387  EM 05  Processetto di Angela di Gerolamo Pellegrin (d...
#
#       number_archival_units  pk_processetto  \
# 7                         1         1007777
# 254                       1         1082330
# 256                       1         1083057
# 344                       1         1103853
# 732                       1         1253962
# 845                       1         1286280
# 959                       1         1339660
# 1150                      1         1508466
# 1625                      1         1680175
# 1689                      1         1700791
# 1728                      1         1721743
# 1946                      1         1790436
# 2003                      1         1799461
# 2018                      1         1802617
# 1689                              Processetto atipico  1596-05-19  1596-05-19
# 1728                        Stato libero di “foresto”  1600-07-09  1600-07-09
# 1946                        Stato libero di “foresto”  1601-07-12  1601-07-12
# 2003                        Stato libero di “foresto”  1596-10-17  1596-10-17
# 2018                        Stato libero di “foresto”  1596-11-02  1596-11-02
# 2019                        Stato libero di “foresto”  1596-11-02  1596-11-02
# 2051                                        Vedovanza  1596-12-07  1596-12-07
# 2124                        Stato libero di “foresto”  1601-02-05  1601-02-05
# 2154                                        Vedovanza  1595-03-24  1595-03-24
# 2163                              Processetto atipico  1601-03-27  1601-03-27
# 2293                        Stato libero di “foresto”  1595-09-17  1595-09-17
# 2295                        Stato libero di “foresto”  1595-09-17  1595-09-17
# 2297                        Stato libero di “foresto”  1595-09-22  1595-09-22
# 2364                        Stato libero di “foresto”  1595-07-09  1595-07-09
# 2391                        Stato libero di “foresto”  1649-12-31  1650-01-17
# 2476                        Stato libero di “foresto”  1650-03-12  1650-03-12
# 2483                        Stato libero di “foresto”  1650-03-25  1650-03-25
# 2768                                        Vedovanza  1620-03-19  1620-03-19
# 2865                        Stato libero di “foresto”  1620-04-29  1620-04-29
# 2894                        Stato libero di “foresto”  1610-01-30  1610-01-30
# 3309                        Stato libero di “foresto”  1597-02-11  1597-02-11
# 3319                        Stato libero di “foresto”  1597-02-17  1597-02-17
# 3339                        Stato libero di “foresto”  1597-02-28  1597-02-28
# 3358                                        Vedovanza  1597-03-29  1597-03-29
# 3383                        Stato libero di “foresto”  1597-04-24  1597-04-24
# 3387                        Stato libero di “foresto”  1598-11-23  1598-11-23
#
#         anno id_union  number_union
# 7     1597.0  1007767             1
# 254   1627.0      NaN             0
# 256   1592.0      NaN             0
# 344   1597.0      NaN             0
# 732   1594.0      NaN             0
# 845   1602.0      NaN             0
# 959   1627.0      NaN             0
# 1150  1604.0      NaN             0
# 1625  1596.0      NaN             0
# 1689  1596.0      NaN             0
# 1728  1600.0      NaN             0
# 1946  1601.0      NaN             0
# 2003  1596.0      NaN             0
# 2018  1596.0      NaN             0
# 2019  1596.0      NaN             0
# 2051  1596.0  1807572             1
# 2124  1601.0      NaN             0
# 2154  1595.0  1855357             1
# 2163  1601.0      NaN             0
# 2293  1595.0      NaN             0
# 2295  1595.0      NaN             0
# 2297  1595.0      NaN             0
# 2364  1595.0      NaN             0
# 2391  1650.0      NaN             0
# 2476  1650.0      NaN             0
# 2483  1650.0      NaN             0
# 2768  1620.0  2088253             1
# 2865  1620.0      NaN             0
# 2894  1610.0      NaN             0
# 3309  1597.0      NaN             0
# 3319  1597.0      NaN             0
# 3339  1597.0      NaN             0
# 3358  1597.0   927943             1
# 3383  1597.0      NaN             0
# 3387  1598.0      NaN             0

# %% [markdown]
# #### Mancanza di motivation type

# %%
# mancanza di motivation type

df_proc[df_proc.motivation_type.isnull()]
# Out:
#      volume                                            section  \
# 775   EM 25  Processetto di Leonardo di Matteo Gallina (da ...
# 1599  EM 06  Processetto di Vincenzo di Giovanni Nante (da ...
# 2030  EM 03  Processetto di Nicolò di Gregorio Andreazzi (d...
# 2041  EM 07  Processetto di Giovanni Battista di Andrea Mol...
# 2549  EM 53  Processetto di Pietro di Nicola Quaia (dalla C...
#
#       number_archival_units  pk_processetto  \
# 775                       1         1270445
# 1599                      1         1675607
# 2030                      1         1804518
# 2041                      1         1806269
# 2549                      1         2018187
#
#                                                 enquiry motivation_type  \
# 775                                          (no label)             NaN
# 1599                                         (no label)             NaN
# 2030  Nicolò di Gregorio Andreazzi (da Monfalcone , ...             NaN
# 2041                                         (no label)             NaN
# 2549      Pietro di Nicola Quaia (dalla Carnia, sartor)             NaN
#
#       start_date    end_date    anno id_union  number_union
# 775          NaN         NaN     NaN      NaN             0
# 1599         NaN         NaN     NaN      NaN             0
# 2030  1596-11-18  1596-11-18  1596.0      NaN             0
# 2041  1603-12-14  1603-12-14  1603.0      NaN             0
# 2549  1650-04-24  1650-04-24  1650.0      NaN             0

# %% [markdown]
# #### Mancanza dell'Union come motivazione del processetto

# %%
# mancanza dell'Union come motivazione del processetto

df_proc[df_proc.motivation_type.str.contains('Vedo') & df_proc.id_union.isnull()]
# Out:
#      volume                                            section  \
# 130   EM 25  Processetto di Enea di Bernardo Illario (da Ve...
# 169   EM 04  Processetto di Elisabetta di Salvatore Colombo...
# 281   EM 25  Processetto di Andrea di Filippo Roat (bresciano)
# 785   EM 25  Alba di Giovanni Codega (da Padova) vedova di ...
# 1382  EM 07           Bandino Guerra (dalla diocesi di Ceneda)
# 1567  EM 06  Processetto di Giovanni Maria di Virgilio Pinz...
# 1713  EM 06  Processetto di Fiammetta vedova di Pietro (ber...
# 1984  EM 07  Processetto di Francesco di Giacomo Peughi (da...
# 2033  EM 03        Processetto di Girolama Nigris (da Venezia)
# 2066  EM 03  Processetto di Apollonia di Cristoforo (carnic...
# 2175  FC 22  Processetto di Teodoro Garagna (dalla Riviera ...
# 2782  EM 53  Processetto di Piera di Sebastiano Trevisan (d...
# 2887  EM 40  Processetto di Margherita vedova di Andrea Rag...
# 2906  EM 40  Processetto di Giovanni di Bernardo Astolfo (m...
# 3216  EM 01  Processetto di Pasquale di Maffeo De Savionibu...
# 3372  EM 04  Processetto di Angela di Domenico Roppa (da Gr...
#
#       number_archival_units  pk_processetto  \
# 130                       1         1055799
# 169                       2         1065023
# 281                       1         1089892
# 785                       1         1271941
# 1382                      1         1578490
# 1567                      1         1665217
# 1713                      1         1714185
# 1984                      1         1796676
# 2033                      1         1805046
# 2066                      1         1809886
# 2175                      1         1858807
# 2782                      1         2089760
# 2887                      1         2109158
# 2906                      1         2117825
# 3216                      1          749101
# 3372                      1          928358
#
#                                                 enquiry  \
# 130     Enea di Bernardo Illario (da Venezia, avvocato)
# 169   Elisabetta di Salvatore Colombo (da Napoli) ve...
# 281                  Andrea di Filippo Roat (bresciano)
# 785   Alba di Giovanni Codega (da Padova) vedova di ...
# 1382           Bandino Guerra (dalla Diocesi di Ceneda)
# 1567      Giovanni Maria di Virgilio Pinzini (mercante)
# 1713            Fiammetta vedova di Pietro (bergamasco)
# 1984  Francesco di Giacomo Peughi (da Padova, tesser...
# 2033                       Girolama Nigris (da Venezia)
# 2066  Apollonia di Cristoforo (carnica), vedova di: ...
# 2175   Teodoro Garagna (dalla Riviera di Salò, famulus)
# 2782  Piera di Sebastiano Trevisan (da Venezia) vedo...
# 2887    Margherita vedova di Andrea Ragona (da Vicenza)
# 2906              Giovanni di Bernardo Astolfo (marzer)
# 3216  Angela De Grigis vedova di Pietro Antonio Carrara
# 3372               Angela di Domenico Roppa (da Grigno)
#
#                      motivation_type  start_date    end_date    anno id_union  \
# 130   Vedovanza; Processetto atipico  1627-07-03  1627-07-03  1627.0      NaN
# 169                        Vedovanza  1597-08-28  1597-08-30  1597.0      NaN
# 281                        Vedovanza  1627-05-24  1627-05-24  1627.0      NaN
# 785   Vedovanza; Processetto atipico  1627-07-06  1627-07-06  1627.0      NaN
# 1382                       Vedovanza  1603-01-26  1603-01-26  1603.0      NaN
# 1567                       Vedovanza  1600-05-24  1600-05-25  1600.0      NaN
# 1713                       Vedovanza  1600-07-05  1600-07-05  1600.0      NaN
# 1984                       Vedovanza  1603-11-23  1603-11-23  1603.0      NaN
# 2033                       Vedovanza  1596-11-21  1596-11-21  1596.0      NaN
# 2066                       Vedovanza  1595-12-31  1595-12-31  1595.0      NaN
# 2175                       Vedovanza  1595-03-28  1595-03-28  1595.0      NaN
# 2782                       Vedovanza  1650-12-06  1650-12-06  1650.0      NaN
# 2887                       Vedovanza  1639-01-16  1639-01-16  1639.0      NaN
# 2906                       Vedovanza  1639-01-22  1639-01-22  1639.0      NaN
# 3216                       Vedovanza  1592-06-07  1592-06-07  1592.0      NaN
# 3372                       Vedovanza  1597-04-08  1597-04-08  1597.0      NaN
#
#       number_union
# 130              0
# 169              0
# 281              0
# 785              0
# 1382             0
# 1567             0
# 1713             0
# 1984             0
# 2033             0
# 2066             0
# 2175             0
# 2782             0
# 2887             0
# 2906             0
# 3216             0
# 3372             0

# %% [markdown]
# #### Presenza di più union
# > Da verifcare

# %%
# presenza di più union 

df_proc[df_proc.number_union>1]
# Out:
#      volume                                            section  \
# 776   EM 04  Processetto di Angela vedova di Francesco Giov...
# 2407  EM 16  Processetto di Sebastiano di Gottardo Murari (...
# 2630  EM 16  Processetto di Caterina vedova di Manolo Manue...
# 3079  EM 17  Processetto di Marietta vedova di Ruggero Pere...
#
#       number_archival_units  pk_processetto  \
# 776                       1         1270509
# 2407                      1         1986329
# 2630                      1         2029147
# 3079                      1         2215939
#
#                                                 enquiry motivation_type  \
# 776   Angela vedova di Francesco Giovanni Ochiati (d...       Vedovanza
# 2407          Sebastiano di Gottardo Murari (da Verona)       Vedovanza
# 2630       Caterina vedova di Manolo Manuelli (cretese)       Vedovanza
# 3079         Marietta vedova di Ruggero Perei (moliner)       Vedovanza
#
#       start_date    end_date    anno         id_union  number_union
# 776   1597-08-05  1597-08-05  1597.0  1270524-1270537             2
# 2407  1620-01-12  1620-01-12  1620.0  1986337-1986343             2
# 2630  1620-02-15  1620-02-15  1620.0  2029154-2107629             2
# 3079  1620-10-02  1620-10-02  1620.0  2215946-2215952             2

# %% [markdown]
# #### Assenza della data del processetto

# %%
# assenza della data del processetto
df_proc[df_proc.anno.isnull()]
# Out:
#      volume                                            section  \
# 99    EM 25  Processetto di Giacomo di Pietro Provezi (da V...
# 118   EM 25  Processetto di Geronimo di Stefano Nicoletti (...
# 775   EM 25  Processetto di Leonardo di Matteo Gallina (da ...
# 1367  EM 06       Processetto di Regina di Giorgio (da Retimo)
# 1562  EM 07  Processetto di Dionora vedova di Domenico di G...
# 1584  EM 06  Processetto di Margherita di Andrea de Angelis...
# 1599  EM 06  Processetto di Vincenzo di Giovanni Nante (da ...
# 2320  FC 22       Processetto di Giacomo di Michele (da Cipro)
# 3163  EM 40  Processetto di Giuseppe di Giacomo Zinia (da C...
#
#       number_archival_units  pk_processetto  \
# 99                        1         1048535
# 118                       1         1053677
# 775                       1         1270445
# 1367                      1         1573529
# 1562                      1         1663914
# 1584                      1         1672770
# 1599                      1         1675607
# 2320                      1         1893341
# 3163                      1         2237272
#
#                                                 enquiry  \
# 99    Giacomo di Pietro Provezi (da Val Cavallina, c...
# 118   Geronimo di Stefano Nicoletti (da Chiampo, tes...
# 775                                          (no label)
# 1367                      Regina di Giorgio (da Retimo)
# 1562   Dionora vedova di Domenico di Giacomo Giovanetti
# 1584        Margherita di Andrea de Angelis (ferrarese)
# 1599                                         (no label)
# 2320                      Giacomo di Michele (da Cipro)
# 3163  Giuseppe di Giacomo Zinia (da Camposampiero, l...
#
#                 motivation_type start_date end_date  anno id_union  \
# 99    Stato libero di “foresto”        NaN      NaN   NaN      NaN
# 118   Stato libero di “foresto”        NaN      NaN   NaN      NaN
# 775                         NaN        NaN      NaN   NaN      NaN
# 1367  Stato libero di “foresto”        NaN      NaN   NaN      NaN
# 1562                  Vedovanza        NaN      NaN   NaN  1663920
# 1584  Stato libero di “foresto”        NaN      NaN   NaN      NaN
# 1599                        NaN        NaN      NaN   NaN      NaN
# 2320  Stato libero di “foresto”        NaN      NaN   NaN      NaN
# 3163  Stato libero di “foresto”        NaN      NaN   NaN      NaN
#
#       number_union
# 99               0
# 118              0
# 775              0
# 1367             0
# 1562             1
# 1584             0
# 1599             0
# 2320             0
# 3163             0

# %% [markdown]
# #### Outline cornologici

# %%
df_proc.groupby('anno').agg({'pk_processetto':'count'}).plot.bar(figsize=(20,10), color='lightgray')
# Out:
# <AxesSubplot:xlabel='anno'>

# %%
# identificazione degli outline


df_proc[df_proc.pk_processetto.isin(df_proc.sort_values(by='anno', na_position='last').pk_processetto.head(2)) | df_proc.pk_processetto.isin(df_proc.sort_values(by='anno', na_position='first').pk_processetto.tail(2))].sort_values(by='anno')
# Out:
#      volume                                            section  \
# 1540  EM 06  Processetto di Pasqua di Michele Iacobati (mas...
# 2271  FC 22  Processetto di Antonio di Leonardo (da Trani, ...
# 2410  EM 53  Processetto di Francesca di Francesco Meneghel...
# 1404  EM 07  Processetto di Gaspare di Gaspare Ballestra (d...
#
#       number_archival_units  pk_processetto  \
# 1540                      1         1657971
# 2271                      1         1884529
# 2410                      1         1986791
# 1404                      1         1616092
#
#                                                 enquiry  \
# 1540               Pasqua di Michele Iacobati (massera)
# 2271            Antonio di Leonardo (da Trani, mariner)
# 2410     Francesca di Francesco Meneghelli (da Cagnola)
# 1404  Gaspare di Gaspare Ballestra (da Leichlingen, ...
#
#                 motivation_type  start_date    end_date    anno id_union  \
# 1540  Stato libero di “foresto”  1061-12-05  1061-12-05  1061.0      NaN
# 2271  Stato libero di “foresto”  1590-08-12  1590-08-12  1590.0      NaN
# 2410  Stato libero di “foresto”  1656-01-06  1656-01-06  1656.0      NaN
# 1404  Stato libero di “foresto”  1693-02-04  1693-02-04  1693.0      NaN
#
#       number_union
# 1540             0
# 2271             0
# 2410             0
# 1404             0

# %%
df_proc[~df_proc.anno.isin(range(1590,1657))&df_proc.anno.notnull()]
# Out:
#      volume                                            section  \
# 1404  EM 07  Processetto di Gaspare di Gaspare Ballestra (d...
# 1540  EM 06  Processetto di Pasqua di Michele Iacobati (mas...
#
#       number_archival_units  pk_processetto  \
# 1404                      1         1616092
# 1540                      1         1657971
#
#                                                 enquiry  \
# 1404  Gaspare di Gaspare Ballestra (da Leichlingen, ...
# 1540               Pasqua di Michele Iacobati (massera)
#
#                 motivation_type  start_date    end_date    anno id_union  \
# 1404  Stato libero di “foresto”  1693-02-04  1693-02-04  1693.0      NaN
# 1540  Stato libero di “foresto”  1061-12-05  1061-12-05  1061.0      NaN
#
#       number_union
# 1404             0
# 1540             0

# %% [markdown]
# -----------------------------

# %% [markdown]
# ## Persone

# %%
def controllo_person(df):
    errore = []
    for i, r in df.iterrows():
        if type(r.genere)== float:
            errore.append('genere mancante')
        else:
            errore.append(np.nan)
        if (r.person.split()[0][-1] == 'a') and r.person.split()[0] not in ['Andrea', 'Battista', 'Nicola', 'Geremia', 'Giovita', 'Enea','Ventura', 'Evangelista', 'Luca' ]:
           
            if (type(r.genere) != float) and 'Femm' not in r.genere:
                  errore[i] = '; '.join([errore[i], 'verifica genere']) if type(errore[i])== str else 'verifica genere'
        if type(r.origini)!=float and '(no label)' in r.origini:
            errore[i] = ';'.join([errore[i], 'origini (no label)']) if type(errore[i])==str else 'origini (no label)'
        
        try: 
            if r['età']<10 or r['età']>70:
                errore[i] = ';'.join([errore[i], 'verifica età']) if type(errore[i])==str else 'verifica età'
        except:
            pass
   
    df['errore'] = errore
    df.errore = df.errore.replace('', np.nan)
      
    return df

# %% [markdown]
# #### Richiedenti

# %%
file = 'geovistory_query_exports/nb_richiedenti_20220510.json'

with open(file, encoding='utf-8') as json_file:
    data_ric = json.load(json_file)

dmr = DotMap(data_ric)

dmr_r = dmr.rows

# %%
# Richiedenti list = rl

rl = [['pk_processetto',  'pk_person', 'person', 'qualità', 'genere', 'origini', 'anno_nascita', 'professioni' ]]


for r in dmr_r:
    for el in r.col_0.entities:
        element = []
        element += [el.pk_entity]

        # pk_person, person, qualità, genere
        element += [r.col_1.entity.pk_entity, clean_up_str(r.col_1.entity.entity_label), 'richiedente', (
            r.col_2.entities[0].entity_label if len(r.col_2.entities)>0 else np.nan)]
        
        # origini
        element += [clean_up_str('; '.join(e.entity_label for e in r.col_3.entities)) if len(r.col_3.entities)>=1 else np.nan]

        # Anno di nascita 
        element += [date(r.col_4)]
        
        # professioni
        element += ['; '.join(e.entity_label for e in r.col_5.entities) if len(r.col_5.entities)>=1 else np.nan]
        
        rl.append(element)


df_ric = pd.DataFrame(rl[1:], columns=rl[0])
df_ric['età'] = df_ric.merge(df_proc[['pk_processetto', 'anno']], on='pk_processetto', how='left')['anno'] - df_ric['anno_nascita']
df_ric = df_ric[['pk_processetto', 'pk_person', 'person', 'qualità', 'età', 'anno_nascita', 'genere', 'origini', 'professioni']]; df_ric.head()
# Out:
#    pk_processetto  pk_person  \
# 0         1006519    1006422
# 1         1006883    1006794
# 2         1007147    1006856
# 3         1007355    1007216
# 4         1007563    1007388
#
#                                               person      qualità   età  \
# 0                  Giovanni di Michele (da Cessalto)  richiedente  21.0
# 1  Pietro di Gennaro Costinovi (da Bergamo, tesse...  richiedente  21.0
# 2            Orsola di Angelo Collotis (da Visinale)  richiedente  26.0
# 3           Ortensia di Leonardo Verona (da Venzone)  richiedente  25.0
# 4  Vincenzo di Battista Betocchi (da Gandino, cas...  richiedente  26.0
#
#    anno_nascita     genere   origini            professioni
# 0        1576.0   Maschile  Cessalto                    NaN
# 1        1576.0   Maschile   Bergamo  cogo; tesser da panni
# 2        1572.0  Femminile  Visinale                 masser
# 3        1573.0  Femminile   Venzone                 masser
# 4        1572.0   Maschile   Gandino               casariol

# %% [markdown]
# -----------------------

# %%
print(f'non è noto l\'anno di nascita per {len(df_ric[df_ric.anno_nascita.isnull()])} richiedenti su {len(df_ric)}. Vanno tuttavia esclusi i vedovi')
# Out:
# non è noto l'anno di nascita per 711 richiedenti su 3429. Vanno tuttavia esclusi i vedovi

# %%
# campione per verifica

df_ric[df_ric.anno_nascita.isnull()].merge(df_proc[df_proc.motivation_type.str.contains('Vedova')==False][['pk_processetto', 'motivation_type', 'volume']], on='pk_processetto')
# Out:
#      pk_processetto  pk_person  \
# 0           1008285    1008160
# 1           1008665    1008475
# 2           1011331    1011249
# 3           1012820    1012536
# 4           1041888    1041834
# ..              ...        ...
# 261          778511     778417
# 262          833146     833043
# 263          836516     836300
# 264          986635     986587
# 265          992246     992063
#
#                                                 person      qualità  età  \
# 0    Domenico di Leonardo Dell’Olivo (da Vito d’Asi...  richiedente  NaN
# 1    Alessandro di Lorenzo Ferrarini (da Clusone, s...  richiedente  NaN
# 2             Antonio di Antonio Poli (da Pré, cester)  richiedente  NaN
# 3    Matteo di Angelo Della Costa (da Posina, samiter)  richiedente  NaN
# 4            Tommaso di Giovanni Maria Turra (filator)  richiedente  NaN
# ..                                                 ...          ...  ...
# 261           Pietro Maria Canipari (da Crema, fisico)  richiedente  NaN
# 262  Francesco di Tommaso Rocchetta (da Rossano, ma...  richiedente  NaN
# 263    Antonio di Antonio Burlis (da Fonzaso, samiter)  richiedente  NaN
# 264  Lorenzo di Antonio Donati (da Marano Veneziano...  richiedente  NaN
# 265  Giacomo di Giovanni Battista Colonne (da Canal...  richiedente  NaN
#
#      anno_nascita    genere           origini  \
# 0             NaN  Maschile       Vito d'Asio
# 1             NaN  Maschile           Clusone
# 2             NaN  Maschile      Pré di Ledro
# 3             NaN  Maschile            Posina
# 4             NaN  Maschile               NaN
# ..            ...       ...               ...
# 261           NaN  Maschile             Crema
# 262           NaN  Maschile           Rossano
# 263           NaN  Maschile            Fondas
# 264           NaN  Maschile  Marano Veneziano
# 265           NaN  Maschile   Canale d'Agordo
#
#                                   professioni  \
# 0       stampador da libri; soldado; scaleter
# 1    servir in bottega de mercante da colori
# 2                                   cestariol
# 3                                     samiter
# 4                                     filator
# ..                                        ...
# 261                                    fisico
# 262                           mariner; masser
# 263                                   samiter
# 264                                    pistor
# 265                                   scultor
#
#                                        motivation_type volume
# 0                            Stato libero di “foresto”  EM 05
# 1                            Stato libero di “foresto”  EM 05
# 2                            Stato libero di “foresto”  EM 05
# 3                            Stato libero di “foresto”  EM 05
# 4                                  Processetto atipico  EM 04
# ..                                                 ...    ...
# 261  Stato libero di persona lungamente assente da ...  EM 01
# 262                          Stato libero di “foresto”  EM 05
# 263                          Stato libero di “foresto”  EM 05
# 264                          Stato libero di “foresto”  EM 05
# 265                          Stato libero di “foresto”  EM 05
#
# [266 rows x 11 columns]

# %% [markdown]
# #### Manca il genere

# %%
# Manca il genere 
df_ric[df_ric.genere.isnull()]
# Out:
#       pk_processetto  pk_person  \
# 989          1342779    1342619
# 1160         1508466    1508259
# 2377         1968914    1968817
# 2395         1986329    1986161
# 2802         2092800    2092781
# 2803         2092956    2092938
# 2804         2093059    2093041
#
#                                                  person      qualità   età  \
# 989   Battista di Francesco Ghedini (da Spinone al L...  richiedente  25.0
# 1160     Defendente di Angelo Pizzali (da Torno, laner)  richiedente  20.0
# 2377    Giovanni di Giacomo Pezzetti (da Buja, samiter)  richiedente  20.0
# 2395          Sebastiano di Gottardo Murari (da Verona)  richiedente  60.0
# 2802  Marietta di Domenico Cruzzoli (da Musano, mass...  richiedente  29.0
# 2803  Caterina di Pietro Pini (da Venezia) vedova di...  richiedente   NaN
# 2804  Giacoma di Domenico Vanini vedova di Pietro (d...  richiedente   NaN
#
#       anno_nascita genere          origini professioni
# 989         1574.0    NaN  Spinone al Lago      masser
# 1160        1584.0    NaN              NaN       laner
# 2377        1576.0    NaN             Buja     samiter
# 2395        1560.0    NaN           Verona         NaN
# 2802        1591.0    NaN           Musano      masser
# 2803           NaN    NaN       Venezia IT         NaN
# 2804           NaN    NaN              NaN         NaN

# %%
def controllo_genere(df):
    controllo = []
    for i,r in df.iterrows():
        if (r.person.split()[0][-1] == 'a') and r.person.split()[0] not in ['Andrea', 'Battista', 'Nicola', 'Geremia', 'Giovita', 'Enea','Ventura', 'Evangelista', ]:
           
              if (type(r.genere) != float) and 'Femm' not in r.genere:
                controllo.append('verifica')
              else:
                controllo.append(np.nan)
        else:
            controllo.append(np.nan)
            

    return controllo

# %%
df_ric['verifica_genere'] = controllo_genere(df_ric)
df_ric[df_ric.verifica_genere.notnull()]
# Out:
#       pk_processetto  pk_person  \
# 2255        masteler; mariner        verifica
# 2443                      NaN        verifica
# 2542                      NaN        verifica
# 2633                      NaN        verifica
# 2647                      NaN        verifica
# 2687                      NaN        verifica
# 2694                      NaN        verifica
# 2754                      NaN        verifica
# 2775                      NaN        verifica
# 2910                      NaN        verifica
# 3039                      NaN        verifica
# 3040                   tesser        verifica
# 3082                      NaN        verifica
# 3232                   masser        verifica
# 3256                   masser        verifica
# 3257                  mariner        verifica
# 3418                   forner        verifica

# %%
df_ric.groupby('età').agg({'pk_person':'count'}).plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='età'>

# %%
df_ric[df_ric['età'].notnull() & (df_ric['età']<14) | (df_ric['età']>60)].merge(df_proc.loc[:, ['pk_processetto', 'volume']], on='pk_processetto', how='left' )
# Out:
#     pk_processetto  pk_person  \
# 0          1055799    1055699
# 1          1079648    1078862
# 2          1252998    1252883
# 3          1291695    1291422
# 4          1511912    1511837
# 5          1550006    1549924
# 6          1616092    1614020
# 7          1657971    1657936
# 8          1662316    1661987
# 9          1850086    1850002
# 10         1854365    1854115
# 11         1855698    1855667
# 12         1865313    1865177
# 13         1885096    1884967
# 14         2192765    2192677
#
#                                                person      qualità    età  \
# 0     Enea di Bernardo Illario (da Venezia, avvocato)  richiedente   70.0
# 1         Orazio di Cesare Bertelli (da Roma, sartor)  richiedente    8.0
# 2              Michele di Ulrico (da Augusta, pistor)  richiedente   68.0
# 3   Antonio di Giovanni Cornali (da Ranzanico, fac...  richiedente    9.0
# 4          Andrea di Pietro Armi (da Bassano, sartor)  richiedente    8.0
# 5   Felicita di Pietro Lorenzi (da San Nicolò di C...  richiedente    8.0
# 6   Gaspare di Gaspare Ballestra (da Leichlingen, ...  richiedente  117.0
# 7                Pasqua di Michele Iacobati (massera)  richiedente -515.0
# 8   Michele di Simone Giuliani (da San Daniele del...  richiedente   11.0
# 9            Gaspare di Giovanni (da Belluno, forner)  richiedente   13.0
# 10  Domenico di Antonio Senestrari (da Castellacci...  richiedente   13.0
# 11                       Ercole (ferrarese, pescador)  richiedente   11.0
# 12                    Lucrezia di Giuseppe (da Udine)  richiedente   12.0
# 13  Giuseppe di Giovanni Del Berettin (aquileiese,...  richiedente   65.0
# 14    Pietro di Angelo Carella (da Salgareda, fachin)  richiedente   11.0
#
#     anno_nascita     genere                   origini  \
# 0         1557.0   Maschile                       NaN
# 1         1586.0   Maschile                   Roma IT
# 2         1526.0   Maschile                   Augusta
# 3         1590.0   Maschile                 Ranzanico
# 4         1594.0   Maschile                   Bassano
# 5         1594.0   Maschile    San Nicolò di Comelico
# 6         1576.0   Maschile               Leichlingen
# 7         1576.0  Femminile                       NaN
# 8         1589.0   Maschile    San Daniele del Friuli
# 9         1588.0   Maschile                   Belluno
# 10        1588.0   Maschile  Castellaccio di Magliaso
# 11        1584.0   Maschile     Territorio di Ferrara
# 12        1583.0  Femminile                     Udine
# 13        1530.0   Maschile      Patriarchat Aquileia
# 14        1619.0   Maschile                 Salgareda
#
#                 professioni verifica_genere volume
# 0                  avvocato             NaN  EM 25
# 1                    sartor             NaN  EM 02
# 2   fante de pistor; pistor             NaN  EM 02
# 3                    fachin             NaN  EM 05
# 4                    sartor             NaN  EM 07
# 5                    masser        verifica  EM 07
# 6                    sartor             NaN  EM 07
# 7                    masser             NaN  EM 06
# 8                       NaN             NaN  EM 06
# 9                    forner             NaN  EM 06
# 10                   latter             NaN  EM 06
# 11                 pescador             NaN  FC 22
# 12                      NaN             NaN  FC 22
# 13               passamaner             NaN  FC 22
# 14                   fachin             NaN  EM 40

# %% [markdown]
# ### Origine (no label)

# %%
df_ric[df_ric.origini.notnull() & df_ric.origini.str.contains('no lab')]
# Out:
#       pk_processetto  pk_person  \
# 759          1258483    1258327
# 1973         1795145    1795075
#
#                                                  person      qualità   età  \
# 759   Vincenzo di Leonardo Bailo (da Palazzolo della...  richiedente  30.0
# 1973  Lorenzo di Giovanni Boccia (da Palazzolo dello...  richiedente  24.0
#
#       anno_nascita    genere     origini professioni verifica_genere
# 759         1569.0  Maschile  (no label)     mariner             NaN
# 1973        1572.0  Maschile  (no label)  squerariol             NaN

# %% [markdown]
# -----------------------------

# %%
controllo_person(df_ric)
df_ric[df_ric.errore.notnull()]
# Out:
#       pk_processetto  pk_person  \
# 248          1079648    1078862
# 454          1127499    1127449
# 572          1152331    1152263
# 640          1199851    1199692
# 738          1253440    1253365
# 751          1255619    1255478
# 759          1258483    1258327
# 865          1291695    1291422
# 968          1339737    1335844
# 989          1342779    1342619
# 1035         1473187    1473096
# 1130         1500071    1498740
# 1160         1508466    1508259
# 1178         1511912    1511837
# 1268         1550006    1549924
# 1360         1570580    1570361
# 1410         1616092    1614020
# 1498         1641990    1641511
# 1547         1657971    1657936
# 1585         1672010    1671593
# 1774         1731555    1731440
# 1816         1750078    1749901
# 1908         1779650    1779504
# 1973         1795145    1795075
# 2024         1803636    1803527
# 2030         1804722    1804578
# 2377         1968914    1968817
# 2395         1986329    1986161
# 2443         1999148    1999054
# 2542         2018614    2018527
# 2633         2030678    2030547
# 2687         2038765    2038745
# 2694         2071107    2071077
# 2754         2087616    2087530
# 2775         2089859    2089782
# 2802         2092800    2092781
# 2803         2092956    2092938
# 2804         2093059    2093041
# 2910         2168827    2168731
# 3039         2204743    2204659
# 3082         2220305    2220171
# 3232          750586     750566
# 3256          759719     759645
# 3418          996437     996361
#
#                                                  person      qualità    età  \
# 248         Orazio di Cesare Bertelli (da Roma, sartor)  richiedente    8.0
# 454      Angela di Pietro Cortella (dalla Valle Sabbia)  richiedente   22.0
# 572   Maddalena di Giacomo Trevisani (da Motta di Li...  richiedente   18.0
# 640   Giovanna (da Venezia) vedova di Antonio Maria ...  richiedente    NaN
# 738         Lucia di Giacomo Tarabotti (da Capodistria)  richiedente   14.0
# 751                 Olivia di Andrea Belfi (dal Cadore)  richiedente   29.0
# 759   Vincenzo di Leonardo Bailo (da Palazzolo della...  richiedente   30.0
# 865   Antonio di Giovanni Cornali (da Ranzanico, fac...  richiedente    9.0
# 968               Maria di Bartolomeo Fagari (da Lamon)  richiedente   20.0
# 968         1582.0   Maschile                             Lamon      masser
# 989         1574.0        NaN                   Spinone al Lago      masser
# 1035        1559.0   Maschile                         Cordovado    camerier
# 1130        1577.0   Maschile                           Bassano      masser
# 1160        1584.0        NaN                               NaN       laner
# 1178        1594.0   Maschile                           Bassano      sartor
# 1268        1594.0   Maschile            San Nicolò di Comelico      masser
# 1360        1566.0   Maschile                        Conegliano    camerier
# 1410        1576.0   Maschile                       Leichlingen      sartor
# 1498        1574.0   Maschile                             Asolo         NaN
# 1547        1576.0  Femminile                               NaN      masser
# 1585           NaN   Maschile                               NaN         NaN
# 1774        1558.0   Maschile  Territorio di Sebenico (Šibenik)         NaN
# 1816        1580.0   Maschile                             Udine      masser
# 1908        1558.0   Maschile             Saviore dell'Adamello         NaN
# 1973        1572.0   Maschile                        (no label)  squerariol
# 2024        1566.0   Maschile                           Treviso         NaN
# 2030           NaN   Maschile                        Venezia IT         NaN
# 2377        1576.0        NaN                              Buja     samiter
# 2395        1560.0        NaN                            Verona         NaN
# 2443        1615.0   Maschile            San Daniele del Friuli         NaN
# 2542        1632.0   Maschile                           Coseano         NaN
# 2633        1628.0   Maschile                     Maastricht NL         NaN
# 2687           NaN   Maschile                               NaN         NaN
# 2694        1585.0   Maschile            San Daniele del Friuli         NaN
# 2754        1618.0   Maschile               Castelfranco Veneto         NaN
# 2775           NaN   Maschile                           Treviso         NaN
# 2802        1591.0        NaN                            Musano      masser
# 2803           NaN        NaN                        Venezia IT         NaN
# 2804           NaN        NaN                               NaN         NaN
# 2910           NaN   Maschile                               NaN         NaN
# 3039        1613.0   Maschile                            Friuli         NaN
# 3082        1617.0   Maschile                            Pirano         NaN
# 3232        1565.0   Maschile                             Creta      masser
# 3256           NaN   Maschile                       Bellunensis      masser
# 3418        1571.0   Maschile                      Troi del Mut      forner
#
#      verifica_genere                        errore
# 248              NaN                  verifica età
# 454         verifica               verifica genere
# 572         verifica               verifica genere
# 640         verifica               verifica genere
# 738         verifica               verifica genere
# 751         verifica               verifica genere
# 759              NaN            origini (no label)
# 865              NaN                  verifica età
# 968         verifica               verifica genere
# 989              NaN               genere mancante
# 1035        verifica               verifica genere
# 1130        verifica               verifica genere
# 1160             NaN               genere mancante
# 1178             NaN                  verifica età
# 1268        verifica  verifica genere;verifica età
# 1360        verifica               verifica genere
# 1410             NaN                  verifica età
# 1498        verifica               verifica genere
# 1547             NaN                  verifica età
# 1585        verifica               verifica genere
# 1774        verifica               verifica genere
# 1816        verifica               verifica genere
# 1908        verifica               verifica genere
# 1973             NaN            origini (no label)
# 2024        verifica               verifica genere
# 2030        verifica               verifica genere
# 2377             NaN               genere mancante
# 2395             NaN               genere mancante
# 2443        verifica               verifica genere
# 2542        verifica               verifica genere
# 2633        verifica               verifica genere
# 2687        verifica               verifica genere
# 2694        verifica               verifica genere
# 2754        verifica               verifica genere
# 2775        verifica               verifica genere
# 2802             NaN               genere mancante
# 2803             NaN               genere mancante
# 2804             NaN               genere mancante
# 2910        verifica               verifica genere
# 3039        verifica               verifica genere
# 3082        verifica               verifica genere
# 3232        verifica               verifica genere
# 3256        verifica               verifica genere
# 3418        verifica               verifica genere

# %% [markdown]
# #### Testimoni

# %%
file = 'geovistory_query_exports/nb_testimoni_20220510.json'

with open(file, encoding='utf8') as json_file:
    data_tes = json.load(json_file)

dmt = DotMap(data_tes)

dmt_r = dmt.rows

# %%
# Testimone list = rl

tl = [['pk_processetto',  'pk_person', 'person', 'qualità', 'genere', 'origini', 'anno_nascita', 'professioni' ]]


for r in dmt_r:
    for el in r.col_0.entities:
        element = []
        element += [el.pk_entity]

        # pk_person, person, qualità, genere
        element += [r.col_1.entity.pk_entity, clean_up_str(r.col_1.entity.entity_label), 'testimone', (
            r.col_2.entities[0].entity_label if len(r.col_2.entities)>0 else np.nan)]
        
        # origini
        element += [clean_up_str('; '.join(e.entity_label for e in r.col_3.entities)) if len(r.col_3.entities) else np.nan]

        # Anno di nascita 
        element += [date(r.col_4)]
        
        # professioni
        element += ['; '.join(e.entity_label for e in r.col_5.entities) if len(r.col_5.entities) else np.nan]
        
        tl.append(element)


df_tes = pd.DataFrame(tl[1:], columns=tl[0])
df_tes['età'] = df_tes.merge(df_proc[['pk_processetto', 'anno']], on='pk_processetto', how='left')['anno'] - df_tes['anno_nascita']
df_tes = df_tes[['pk_processetto', 'pk_person', 'person', 'qualità', 'età', 'anno_nascita', 'genere', 'origini', 'professioni']]; df_tes.head()
# Out:
#    pk_processetto  pk_person  \
# 0         1006729    1002990
# 1         1006519    1006430
# 2         1006519    1006438
# 3         1006519    1006449
# 4         1006883    1006806
#
#                                               person    qualità   età  \
# 0  Giuseppe di Francesco Domiziano (da Fabriano, ...  testimone  53.0
# 1              Pietro di Giovanni Maria (da Venezia)  testimone  54.0
# 2  Antonio di Ambrogio Didano (da Bergamo, vender...  testimone  26.0
# 3  Frizerio di Antonio Zuliani (da Venezia, pesca...  testimone  38.0
# 4  Ludovico di Ludovico Morando (da Bergamo, tess...  testimone  39.0
#
#    anno_nascita    genere     origini       professioni
# 0        1545.0  Maschile    Fabriano  cimador da panni
# 1        1543.0  Maschile  Venezia IT               NaN
# 2        1571.0  Maschile     Bergamo        vender vin
# 3        1559.0  Maschile  Venezia IT               NaN
# 4        1558.0  Maschile     Bergamo   tesser da panni

# %%
controllo_person(df_tes)
df_tes[df_tes.errore.notnull()]
# Out:
#       pk_processetto  pk_person  \
# 17           1007933    1007886
# 75           1032025    1031948
# 146          1041471    1041297
# 173          1044060    1045167
# 209          1048915    1048889
# ...              ...        ...
# 6840          776278     776094
# 6902          832921     832736
# 6937          929116     929005
# 6987          991619     991473
# 7008          996437     996370
#
#                                                  person    qualità   età  \
# 17     Antonio di Antonio Grappolino Bertolini (masser)  testimone  64.0
# 75    Battista di Giovanni Boralli (da Padova, barbier)  testimone  87.0
# 146   Giovanni di Domenico di Cecco (da Cividale del...  testimone  73.0
# 173            Lorenzo di Marco Bortazzolo (da Treviso)  testimone  43.0
# 209   Domenico di Giovanni Battista Chiandolo (da Mo...  testimone   7.0
# ...                                                 ...        ...   ...
# 6840  Filippa vedova di Sebastiano Piniatelli (della...  testimone   5.0
# 6902  Andrea di Bernardo Furlanetto (da Sacile, sartor)  testimone  76.0
# 6937            Battista di Giovanni Padovano (barbier)  testimone  87.0
# 6987               Anna moglie di Paolo Pelix (batioro)  testimone   0.0
# 7008  Battista di Giovanni Falconi (da Venezia, forner)  testimone  76.0
#
#       anno_nascita     genere              origini professioni  \
# 17          1533.0        NaN                  NaN      masser
# 75          1510.0   Maschile               Padova     barbier
# 146         1554.0   Maschile  Cividale del Friuli     coroner
# 173         1554.0        NaN                  NaN         NaN
# 209         1620.0   Maschile          Mortegliano         NaN
# ...            ...        ...                  ...         ...
# 6840        1587.0  Femminile            Lusitania         NaN
# 6902        1522.0   Maschile               Sacile      sartor
# 6937        1510.0   Maschile                  NaN     barbier
# 6987        1598.0  Femminile                  NaN         NaN
# 7008        1521.0   Maschile           Venezia IT      forner
#
#                errore
# 17    genere mancante
# 75       verifica età
# 146      verifica età
# 173   genere mancante
# 209      verifica età
# ...               ...
# 6840     verifica età
# 6902     verifica età
# 6937     verifica età
# 6987     verifica età
# 7008     verifica età
#
# [138 rows x 10 columns]

# %% [markdown]
# ### Defunti

# %%
file = 'geovistory_query_exports/nb_defunti_20220510.json'

with open(file, encoding='utf-8') as json_file:
    data_def = json.load(json_file)

dmd = DotMap(data_def)

dmd_r = dmd['rows']

# %%
# Defunti list = dl
#'pk_processetto', 'pk_person', 'person', 'qualità', 'età', 'anno_nascita', 'genere', 'origini', 'professioni',]]

dl = [['pk_person', 'person', 'qualità', 'genere', 'origini', 'professioni', 'anno_nascita', 'anno_morte', 'luogo_morte', 'id_union', 'union_count', 'type_union', 'pk_person(partner)', 'partner', 'pk_processetto']]

for r in dmd_r:
    element=[]

    # pk_person, person, qualità, genere, origini, professioni
    element += [r.col_0.entity.pk_entity, clean_up_str(r.col_0.entity.entity_label), 'defunto', (r.col_1.entities[0].entity_label if len(r.col_1.entities)>0 else np.nan), (
        ('; '.join(e.entity_label for e in r.col_2.entities)) if len(r.col_2.entities)>=1 else np.nan), ('; '.join(e.entity_label for e in r.col_4.entities) if len(r.col_4.entities)>=1 else np.nan)]

    # anno_nascita
    element += [date(r.col_3)]

    # anno_morte, luogo_morte
    element += [date(r.col_6), ('; '.join(e.entity_label for e in r.col_7.entities) if len(r.col_7.entities)>=1 else np.nan)]
    
    # union, conteggio_unioni, tipo unione
    element += ['-'.join([str(v.pk_entity) for v in r.col_8.entities]) if len(r.col_8.entities)>=1 else np.nan, len(r.col_8.entities), (
        '; '.join(e.entity_label for e in r.col_9.entities) if len(r.col_9.entities)>=1 else np.nan)]
    
    # pk_person(partner), partner
    ## riscrivi
    id_part, part = [], []
    for e in r.col_10.entities:
        if e.pk_entity != r.col_0.entity.pk_entity:
            id_part.append(e.pk_entity)
            part.append(clean_up_str(e.entity_label))
    element += [('-'.join(str(e) for e in id_part) if len(id_part)>=1 else np.nan), ('; '.join(part) if len(part)>=1 else np.nan)]
          
    # pk_processetto
    element += ['-'.join([str(v.pk_entity) for v in r.col_11.entities]) if len(r.col_11.entities)>=1 else np.nan]

    dl.append(element)

df_defs = pd.DataFrame(dl[1:], columns=dl[0])
df_defs.head()
# Out:
#    pk_person                                      person  qualità     genere  \
# 0    1007544                          Battista di Nicola  defunto   Maschile
# 1    1007750                         Angela (da Bergamo)  defunto  Femminile
# 2    1013001              Francesco Bettinelli (curamer)  defunto   Maschile
# 3    1032159         Marco Antonio di Francesco Galeotto  defunto   Maschile
# 4    1038739  Giovanni di Domenico (da Trieste, mariner)  defunto   Maschile
#
#                  origini    professioni  anno_nascita  anno_morte luogo_morte  \
# 0                    NaN  paron de nave        1543.0      1595.0         NaN
# 1  Territorio di Bergamo            NaN           NaN      1596.0         NaN
# 2                    NaN        curamer           NaN      1590.0   S. Aponal
# 3             Venezia IT            NaN           NaN      1590.0   S. Martin
# 4             Trieste IT        mariner           NaN      1597.0       Zante
#
#   id_union  union_count            type_union pk_person(partner)  \
# 0  1007670            1  Matrimonio cattolico            1007492
# 1  1007767            1  Matrimonio cattolico            1007715
# 2  1026547            1  Matrimonio cattolico            1012979
# 3  1032511            1  Matrimonio cattolico            1032116
# 4  1038920            1  Matrimonio cattolico            1038725
#
#                                              partner pk_processetto
# 0                 Santa vedova di Battista di Nicola        1007675
# 1                          Filippo Amis (da Bergamo)        1007777
# 2  Caterina Albrizzi vedova di Francesco Bettinel...        1026527
# 3  Bradamante di Francesco Canano (da Pordenone) ...        1032502
# 4  Caterina di Antonio Manzoni vedova di Giovanni...        1038911

# %%
# Integrazione 'controllo person' per defunti
def controllo_def(df):
    errore = []
    df.anno_morte.fillna(0, inplace=True)
    for i, r in df.iterrows():
        errore.append(r.errore)
        if r.anno_morte == 0:
            errore[i] = '; '.join([r.errore, 'anno della morte mancante']) if type(r.errore)!= float else 'anno morte mancante'
        if type(r.id_union) != str:
            errore[i] = '; '.join([r.errore, 'not in union']) if type(r.errore)!=float else 'not in union'
        if type(r.type_union)!=str:
            errore[i]  = '; '.join([r.errore, 'union type mancante']) if type(r.errore)!=float else 'union type mancante'
        if type(r.partner)!=str:
            errore[i] = '; '.join([r.errore, 'partner mancante']) if type(r.errore)!=float else 'partner mancante'

    df['errore'] = errore
    return df   
    # Da completare     


controllo_def(controllo_person(df_defs))

df_defs[df_defs.errore.notnull()]
# Out:
#      pk_person                                             person  qualità  \
# 13     1052687                            Sabata di Floriano Moni  defunto
# 30     1090033         Giuseppe di Baldassarre Malotti (grigione)  defunto
# 32     1092806                                   Giulia di Maffeo  defunto
# 44     1120150                                    Giacomo Grisoni  defunto
# 89     1282009                             Pietro (da Serravalle)  defunto
# 104    1343336                                      Geronimo Luna  defunto
# 105    1464123                  Margherita Boscheria (da Vicenza)  defunto
# 106    1464781                                    Giulia Lombarda  defunto
# 110    1468043                       Fabrizio Stoppa (da Treviso)  defunto
# 126    1508518                          Giovanni di Domenico Bibi  defunto
# 163    1646310                         Iana (da La Canea, comito)  defunto
# 174    1663362                   Cristoforo Baldelli (da Endenna)  defunto
# 175    1671607                                    Andrea Benacase  defunto
# 176    1671709                        Giovanni Battista (botoner)  defunto
# 186    1708157                                   Zaccaria Bolponi  defunto
# 196    1745023          Cecilia Miotto, vedova di Bortolo Perotti  defunto
# 199    1759779                                  Paola (da Padova)  defunto
# 210    1777082  Domenico di Mario De Francesco (da Gradisca, s...  defunto
# 212    1783354                     Innocente Donaio (da Chioggia)  defunto
# 213    1786593                     Marino (da Novegradi, mariner)  defunto
# 225    1800944                Lucia di Biagio Augustini (carnica)  defunto
# 232    1807313             Giovanni Dragani (da Venezia, samiter)  defunto
# 235    1808894           Pietro di Andrea Colledani (fila canevo)  defunto
# 237    1809801        Gesualdo di Leonardo Dai Giudici (cadorino)  defunto
# 243    1822975     Bartolo Bortolussi (da Montereale, polverista)  defunto
# 266    1892776                        Antonio (da Creta, mariner)  defunto
# 267    1895846  Matteo di Andrea Mistri (da Venezia, scrivan d...  defunto
# 274    1979802                       Francesco di Matteo Galeazzo  defunto
# 276    1983838           Giovanna di Antonio Patisti (da Venezia)  defunto
# 277    1984324          Giovanni di Peregrino Vitali (da Bassano)  defunto
# 279    1984652  Giovanni Battista Perici (dalla val Seriana, c...  defunto
# 281    1988074            Giacomo Govarina (da Gradisca, soldato)  defunto
# 295    2013233                                      Nicolò Vuggin  defunto
# 318    2025665         Pietro Antonio Carlini Orioli (da Ravenna)  defunto
# 331    2032414  Pasqua moglie di Giacomo di Giacomo Barbagiò (...  defunto
# 348    2075284                     Girolamo (da Ferrara, soldado)  defunto
# 412    2189682        Vienna Pierotti (da Lucca, arte della seda)  defunto
# 415    2191840                                   Girolama Bianchi  defunto
#
#         genere                origini      professioni  anno_nascita  \
# 13   Femminile                    NaN              NaN           NaN
# 30    Maschile   Cantone dei Grigioni              NaN           NaN
# 32         NaN                    NaN              NaN           NaN
# 44    Maschile                    NaN              NaN           NaN
# 89         NaN                    NaN              NaN           NaN
# 104   Maschile                    NaN              NaN           NaN
# 105  Femminile             Vicenza IT              NaN           NaN
# 106  Femminile                    NaN              NaN           NaN
# 110   Maschile                Treviso              NaN           NaN
# 126        NaN                    NaN              NaN           NaN
# 163   Maschile               La Canea           comito        1549.0
# 174   Maschile                Endenna              NaN           NaN
# 175   Maschile                    NaN              NaN           NaN
# 176   Maschile                    NaN          botoner           NaN
# 186   Maschile                    NaN              NaN           NaN
# 196   Maschile                    NaN              NaN           NaN
# 199  Femminile                 Padova           masser           NaN
# 210   Maschile               Gradisca        stampador           NaN
# 212   Maschile               Chioggia              NaN           NaN
# 213   Maschile              Cittanova          mariner           NaN
# 225   Maschile                    NaN              NaN           NaN
# 232        NaN                    NaN          samiter           NaN
# 235   Maschile                    NaN      fila canevo           NaN
# 237   Maschile                    NaN              NaN           NaN
# 243   Maschile  Montereale Valcellina       polverista           NaN
# 266   Maschile                  Creta          mariner           NaN
# 267   Maschile             Venezia IT  scrivan de nave           NaN
# 274   Maschile             Vicenza IT          soldado           NaN
# 276  Femminile             Venezia IT              NaN           NaN
# 277   Maschile                Bassano              NaN           NaN
# 279   Maschile            Val Seriana          capitan           NaN
# 281   Maschile                    NaN          soldado           NaN
# 213  union type mancante
# 225      verifica genere
# 232      genere mancante
# 235     partner mancante
# 237  anno morte mancante
# 243  anno morte mancante
# 266  union type mancante
# 267  anno morte mancante
# 274  union type mancante
# 276  union type mancante
# 277  union type mancante
# 279  union type mancante
# 281  anno morte mancante
# 295  union type mancante
# 318  anno morte mancante
# 331  anno morte mancante
# 348  anno morte mancante
# 412      verifica genere
# 415      verifica genere

# %% [markdown]
# ### Person name

# %%
file = 'geovistory_query_exports/nb_person_name_20220518.json'
with open(file, encoding='utf-8') as json_file:
    data_name = json.load(json_file)

dmpn = DotMap(data_name)
dmpn_r = dmpn.rows

# %%
def bon_str(string):
    if type(string) == str and (string != ''):
        string = string.strip().replace('\xa0', '').replace('  ', ' ').lower()
    return string

# Person name list = pnl

pnl = [['pk_person', 'person', 'cognome', 'cognome_count', 'titolo_rispetto', 'titolo_professionale']]

for r in dmpn_r:
    element = []
    element += [r.col_0.entity.pk_entity, r.col_0.entity.entity_label, clean_up_str('; '.join(c.entity_label for c in r.col_1.entities)), len(r.col_1.entities) , bon_str('; '.join(tr.entity_label for tr in r.col_2.entities)),
     bon_str('; '.join(tp.entity_label for tp in r.col_3.entities))]
    pnl.append(element)

df_name = pd.DataFrame(pnl[1:], columns=pnl[0])
df_name.replace('', np.nan, inplace=True)

# %%
df_name
# Out:
#        pk_person                                             person  \
# 0        1002990  Giuseppe di Francesco Domiziano (da Fabriano, ...
# 1        1006422                 Giovanni di Michele (da Cessalto)
# 2        1006430             Pietro di Giovanni Maria  (da Venezia)
# 3        1006438  Antonio di Ambrogio Didano (da Bergamo, vender...
# 4        1006449  Frizerio di Antonio Zuliani (da Venezia, pesca...
# ...          ...                                                ...
# 10837     999563             Giovanni di Antonio Maiti (da Bergamo)
# 10838     999580  Vincenzo di Pasini Maiti (da Bergamo, mercante...
# 10839     999599   Francesco di Vincenzo Moscato (da Fabriano, t...
# 10840     999628  Giacomo di Giulio Zambellini (da Bergamo, vend...
# 10841     999827  Angelo di Domenico Venturino (da Fabriano, mer...
#
#           cognome  cognome_count titolo_rispetto titolo_profesisonale
# 0       Domiziano              1             NaN                  NaN
# 1             NaN              0             NaN                  NaN
# 2             NaN              0             ser                  NaN
# 3          Didano              1             ser                  NaN
# 4         Zuliani              1             ser                  NaN
# ...           ...            ...             ...                  ...
# 10837       Maiti              1             NaN                  NaN
# 10838       Maiti              1             ser                  NaN
# 10839     Moscato              1          domino                  NaN
# 10840  Zambellini              1             ser                  NaN
# 10841   Venturino              1          domino                  NaN
#
# [10842 rows x 6 columns]

# %%
titoli_r = []
for i,r in df_name.iterrows():
    if type(r.titolo_rispetto)==str:
        for el in r.titolo_rispetto.split('; '):
            titoli_r.append(el)

titoli_r = [e for e in set(titoli_r)]
# print(titoli_r)
titoli_r = ['nobile veneto', 'domino conte', 'illustrissima domina', 'reverendo frate', 'magnifica', 'nobile veronese', 'eccellentissimo domino', 'illustrissimo cavaliere', 'signora', 'domino', 'messer', 'conte', 'eccellente domino', 'reverendissimo', 'clarissimo', 'reverendo domino', 'eccellentissimo', 'illustrissimo', 'clarissima', 'nobile vicentino', 'messer dominus', 'madonna domina', 'magnifico ed eccellentissimo domino', 'eccelentissimo domino', 'ser', 'magnifico e eccellentissimo domino', 'eccellente', 'illustrissimo domino', 'conte e cavaliere', 'messera', 'magnifica domina', 'domina', 'illustrissimo e reverendissimo', 'nobile', 'clarissima domina', 'clarissimo domino', 'cittadino veneziano', 'signor', 'don', 'reverendo', 'dominus', 'clarisssimo domino', 'eccellentissimo ', 'nobile domina', 'reverendo don', 'madonna', 'vir honestissimus dominus', 'strenuo', 'domini','magnifico',  'nobile domino', 'magnifico domino']

# %%
titoli_p = []
for i,r in df_name.iterrows():
    if type(r.titolo_professionale)==str:
        for el in r.titolo_professionale.split('; '):
            titoli_p.append(el)

titoli_p = [e for e in set(titoli_p)]
print(titoli_p)
# Out:
# ['ser', 'patron', 'magister', 'capitano', 'reverendo pre', 'presbitero', 'maestro', 'dottotre (artium et medicinae doctor)', 'ambasciatore', 'prete', 'reverendo', 'reverendo presbitero']

# %%
def add_controllo(elemento, testo):
    if type(elemento)==str:
        return elemento + f'; {testo}'
    else:
        return testo





controllo = []

for i, r in df_name.iterrows():
    if len(r.person.split())==1 & (e.lower() not in titoli_r):
            controllo.append('PT errore')
    elif e.lower() in titoli_r:
        controllo.append('PT errore')
    else:
        controllo.append(np.nan)

    if type(r.cognome) != float:
        for el in r.cognome.split('; '):
            if (el.lower() in titoli_r):
                controllo[i] = add_controllo(controllo[i], 'titolo in cognome')
                
    if type(r.titolo_rispetto)!=float:
        for el in r.titolo_rispetto.split('; '):
            if el not in titoli_r:
                controllo[i] = add_controllo(controllo[i], 'titolo errato')
        if (len(r.titolo_rispetto.split('; '))==2) and  (r.titolo_rispetto.split('; ')[0] ==r.titolo_rispetto.split('; ')[1]):
                controllo[i] = add_controllo(controllo[i], 'titolo raddoppiato')
    
    if type(r.titolo_professionale)!=float:
        for el in r.titolo_professionale.split('; '):
            if el in titoli_r:
                controllo[i] =  add_controllo(controllo[i], 'titolo errato')

df_name['errore'] = controllo
df_name[df_name.errore.notnull()]
# Out:
#        pk_person                                             person  \
# 57       1012149  Ludovico di Faustino Faustini (da Pregasio, sp...
# 204      1041135            Antonio di Cesare (da Venezia, coroner)
# 211      1041410       Agricane Dalla Torre (diacono de San Samuel)
# 237      1044079  Francesco Paladini (da Pago, canonico de Santa...
# 393      1054933      Marietta di Antonio Gastaldione (da Flagogna)
# ...          ...                                                ...
# 10634     828548                                             Priuli
# 10706     929317  Battista di Alessandro Tricanati (da Tarvisio,...
# 10719     945953              Paolo di Pietro Minoli (da Zandobbio)
# 10803     994175  Giacomo di Simone Coriscelli (da Forni di Sopr...
# 10827     998430  Valentino di Reginaldo Zorpelloni (da Bassano,...
#
#                    cognome  cognome_count               titolo_rispetto  \
# 57           ser; Faustini              2                           NaN
# 204                    NaN              0                domino; domino
# 211            Dalla Torre              1  reverendo presbitero; domino
# 237               Paladini              1  domino; reverendo presbitero
# 393    Gastaldione; Domina              2                           NaN
# ...                    ...            ...                           ...
# 10634               Priuli              1                           NaN
# 10706            Tricanati              1                           NaN
# 10719               Minoli              1                      ser; ser
# 10803      ser; Coriscelli              2                           NaN
# 10827                  NaN              0               zorpelloni; ser
#
#       titolo_professionale              errore
# 57                     NaN   titolo in cognome
# 204                    NaN  titolo raddoppiato
# 211                    NaN       titolo errato
# 237                    NaN       titolo errato
# 393                    NaN   titolo in cognome
# ...                    ...                 ...
# 10634                  NaN           PT errore
# 10706                  ser       titolo errato
# 10719                  NaN  titolo raddoppiato
# 10803                  NaN   titolo in cognome
# 10827                  NaN       titolo errato
#
# [131 rows x 7 columns]

# %%
file = 'geovistory_query_exports/nb_loclaisation_20220512.json'

with open(file, encoding='utf-8') as json_file:
    data_loc = json.load(json_file)

dml = DotMap(data_loc)

dml_r = dml.rows

# %%
# Localisation list = ll

ll = [['id_locaisation', 'pk_person', 'person', 'geographical_place', 'GP_type', 'lat', 'lon', 'localisation_type', 'begin', 'at_some_time', 'end', 'occours_before', 'occours_after']]

for r in dml_r:
    element = []

    # id_localisatio, pk_person, person, geo_place + (id), 
    ## valuta la comodità di tenere separato l'ID geographical Place, geographical place, type, coordinate (x,y), localization type 
    element += [r.col_0.entity.pk_entity, r.col_1.entities[0].pk_entity, clean_up_str(r.col_1.entities[0].entity_label), (r.col_2.entities[0].entity_label + f' ({ r.col_2.entities[0].pk_entity})')  if len(
        r.col_2.entities)>0 else np.nan, r.col_10.entities[0].entity_label if len(r.col_10.entities)>=1 else np.nan]
    if len(r.col_12['values'])>0:    
        element += [r.col_12['values'][0].value.geometry.geoJSON.coordinates[0], r.col_12['values'][0].value.geometry.geoJSON.coordinates[1]]
    else:
        element +=[np.nan, np.nan]
    element += [r.col_11.entities[0].entity_label if len(r.col_11.entities)>0 else np.nan]

    # Begin
    element += [round(np.mean([int(r.col_3['values'][0].value.timePrimitive.label[:4]), int(r.col_4['values'][0].value.timePrimitive.label[:4])])) if (len(r.col_3['values'])>0) and (len(r.col_4['values'])>0) else int(
        r.col_3['values'][0].value.timePrimitive.label[:4]) if (len(r.col_3['values'])>0) else int(r.col_4['values'][0].value.timePrimitive.label[:4]) if len(r.col_4['values'])>0 else np.nan]
    
    # At some time within
    element += [int(r.col_5['values'][0].value.timePrimitive.label[:4]) if len(r.col_5['values'])>0 else np.nan]

    # End
    element += [round(np.mean([int(r.col_6['values'][0].value.timePrimitive.label[:4]), int(r.col_7['values'][0].value.timePrimitive.label[:4])])) if (len(r.col_6['values'])>0) and (len(r.col_7['values'])>0) else int(
        r.col_6['values'][0].value.timePrimitive.label[:4]) if (len(r.col_6['values'])>0) else int(r.col_7['values'][0].value.timePrimitive.label[:4]) if len(r.col_7['values'])>0 else np.nan]
  
  
    # Occours before
    element += ['-'.join(str(v.pk_entity) for v in r.col_8.entities) if len(r.col_8.entities)>0 else np.nan]
    
    # Occours after
    element += ['-'.join(str(v.pk_entity) for v in r.col_9.entities) if len(r.col_9.entities)>0 else np.nan]
    
    ll.append(element)

df_loc = pd.DataFrame(ll[1:], columns=ll[0])
df_loc.head()
